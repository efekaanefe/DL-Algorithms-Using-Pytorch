# %%
# Props to this sensei
# https://www.youtube.com/watch?v=kCc8FmEb1nY&list=PLAqhIrjkxbuWI23v9cThsA9GvCAUhRvKZ&index=8

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

from torch.autograd import Variable
import torch.nn.functional as F


from tqdm import tqdm # progress bar

device = ("cuda" if torch.cuda.is_available() else "mps"
          if torch.backends.mps.is_available() else "cpu")
print(f"Using {device} device")
torch.set_default_device(device)
# Out:
# Using cuda device

# %% [markdown]
# ## Hyper-parameters

# %%
text_file = "tiny-shakespeare.txt"
batch_size = 32 # how many blocks will be given to model
block_size = 12 # context length
max_iters = 3000
learning_rate = 1e-2
eval_interval = 300
eval_iters = 200

# %% [markdown]
# ## Reading Data

# %%
# read file
with open(text_file, "r") as f:
    text = f.read()
text[:100]
# Out:
# 'First Citizen:\nBefore we proceed any further, hear me speak.\n\nAll:\nSpeak, speak.\n\nFirst Citizen:\nYou'

# %%
char_list = sorted(list(set(text)))
char_size = len(char_list)
print(f"All the characters in the text: {''.join(char_list)}")
print(f"Length of the characters: {char_size}")
# Out:
# All the characters in the text:
#  !$&',-.3:;?ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz
# Length of the characters: 65

# %% [markdown]
# ## Tokenizer (character based, index/ascii)

# %%
class MyTokenizer:
    def __init__(self):
        self.char_to_index = None
        self.index_to_char = None

    def fit(self, char_list):  
        self.char_to_index = {char: idx for idx, char in enumerate(char_list)}
        self.index_to_char = {idx: char for char, idx in self.char_to_index.items()}

    def encode_index(self, input_str):
        return [self.char_to_index[char] for char in input_str]

    def decode_index(self, encoded_list):
        return ''.join([self.index_to_char[idx] for idx in encoded_list])

    @staticmethod
    def ascii_tokenizer(char):
        return ord(char)

    @staticmethod
    def ascii_decoder(ascii_value):
        return chr(ascii_value)

    def encode_combined(self, input_str, use_ascii=False):
        if use_ascii:
            return [self.ascii_tokenizer(char) for char in input_str]
        else:
            return self.encode_index(input_str)

    def decode_combined(self, encoded_list, use_ascii=False):
        if use_ascii:
            return ''.join([self.ascii_decoder(ascii_value) for ascii_value in encoded_list])
        else:
            return self.decode_index(encoded_list)

# %%
# Example usage:
tokenizer = MyTokenizer()
tokenizer.fit(char_list)

input_str = "Hello there"
encoded_list_ascii = tokenizer.encode_combined(input_str, use_ascii=True)
decoded_str_ascii = tokenizer.decode_combined(encoded_list_ascii, use_ascii=True)

encoded_list_index = tokenizer.encode_combined(input_str, use_ascii=True)
decoded_str_index = tokenizer.decode_combined(encoded_list_index, use_ascii=True)

print("Original String:", input_str)
print("Encoded List (ASCII):", encoded_list_ascii)
print("Decoded String (ASCII):", decoded_str_ascii)

print("Encoded List (Index):", encoded_list_index)
print("Decoded String (Index):", decoded_str_index)
# Out:
# Original String: Hello there
# Encoded List (ASCII): [72, 101, 108, 108, 111, 32, 116, 104, 101, 114, 101]
# Decoded String (ASCII): Hello there
# Encoded List (Index): [72, 101, 108, 108, 111, 32, 116, 104, 101, 114, 101]
# Decoded String (Index): Hello there

# %%
# Encode all the data and split into train and val
encoded_data = torch.tensor(tokenizer.encode_combined(text))
n = int( 0.9 * len(encoded_data))

train_data = encoded_data[:n]
val_data = encoded_data[n:]

train_data[:block_size + 1]
# Out:
# tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52], device='cuda:0')

# %%
x = train_data[0:block_size]
y = train_data[1:block_size+1]

for t in range(block_size):
    context = x[:t+1]
    target = y[t]
    
    print(f"when input is {context} the target: {target}")
# Out:
# when input is tensor([18], device='cuda:0') the target: 47
# when input is tensor([18, 47], device='cuda:0') the target: 56
# when input is tensor([18, 47, 56], device='cuda:0') the target: 57
# when input is tensor([18, 47, 56, 57], device='cuda:0') the target: 58
# when input is tensor([18, 47, 56, 57, 58], device='cuda:0') the target: 1
# when input is tensor([18, 47, 56, 57, 58,  1], device='cuda:0') the target: 15
# when input is tensor([18, 47, 56, 57, 58,  1, 15], device='cuda:0') the target: 47
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47], device='cuda:0') the target: 58
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58], device='cuda:0') the target: 47
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47], device='cuda:0') the target: 64
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64], device='cuda:0') the target: 43
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43], device='cuda:0') the target: 52

# %%
def get_batch(split):
    data = train_data if split == "train" else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,)) # tensor of random indexes (batch_size, )
    x = torch.stack([data[i:i+block_size] for i in ix]) # from the random index go until block_size, for all random indexes
    y = torch.stack([data[i+1:i+block_size+1] for i in ix]) # from the random index+1 go until block_size+1, for all random indexes
    return x,y 

xb, yb = get_batch("train") # xb -> input to the transformer
print("inputs: ")
print(xb.shape)
print(xb)

print("targets: ")
print(yb.shape)
print(yb)

for b in range(batch_size): # batch dimension
    for t in range(block_size): # time dimension
        context = xb[b, :t+1]
        target = yb[b,t]
        print(f"when input is {context.tolist()} the target: {target}")
# Out:
# inputs:
# torch.Size([32, 12])
# tensor([[43, 56, 39, 50, 42, 10,  0, 19, 47, 60, 43,  1],
#         [ 1, 44, 53, 52, 42, 50, 63,  1, 45, 39, 60, 43],
#         [ 1, 43, 63, 43, 57,  8,  0, 32, 46, 43, 56, 43],
#         [53,  1, 53, 59, 56,  1, 41, 53, 51, 54, 50, 53],
#         [ 0, 16, 43, 57, 47, 56, 43,  1, 58, 53,  1, 40],
#         [ 1, 57, 53, 52,  6,  1, 52, 53, 61,  1, 47, 52],
#         [57,  1, 61, 47, 58, 46,  1, 39, 52,  1, 47, 52],
#         [58,  1, 54, 56, 53, 60, 43,  1, 39,  1, 61, 46],
#         [53, 59, 56,  1, 51, 53, 57, 58,  1, 53, 44, 44],
#         [53, 58,  6,  1, 63, 53, 59, 56,  1, 44, 39, 58],
#         [42, 43,  1, 39,  1, 54, 56, 43, 39, 41, 46, 51],
#         [43, 11,  0, 14, 59, 58,  1, 61, 46, 43, 58, 46],
#         [47, 57, 46,  1, 46, 43, 52, 41, 43,  1, 58, 46],
#         [ 1, 51, 63,  1, 40, 56, 39, 47, 52,  6,  1, 40],
#         [54, 39, 56, 58,  1, 58, 46, 39, 58,  1, 47, 57],
#         [46,  1, 46, 53, 58,  1, 63, 53, 59, 58, 46,  0],
#         [56,  1, 52, 43, 62, 58,  1, 42, 39, 63,  6,  1],
#         [ 1, 61, 46, 43, 52,  1, 39,  1, 49, 47, 52, 45],
#         [54, 50, 43, 39, 57, 59, 56, 43, 11,  0, 13, 63],
#         [43,  6,  1, 40, 59, 58,  1, 20, 59, 51, 54, 46],
#         [ 1, 39,  1, 45, 53, 50, 42, 43, 52,  1, 57, 43],
#         [47, 57,  1, 44, 43, 39, 56, 44, 59, 50,  1, 42],
#         [ 1, 57, 58, 39, 56, 58, 50, 43, 42,  6,  1, 61],
#         [43,  6,  0, 13, 52, 42,  1, 57, 58, 39, 56, 58],
#         [53, 44, 43, 57, 57,  6,  1, 21,  1, 61, 47, 50]], device='cuda:0')
# when input is [43] the target: 56
# when input is [43, 56] the target: 39
# when input is [43, 56, 39] the target: 50
# when input is [43, 56, 39, 50] the target: 42
# when input is [43, 56, 39, 50, 42] the target: 10
# when input is [43, 56, 39, 50, 42, 10] the target: 0
# when input is [43, 56, 39, 50, 42, 10, 0] the target: 19
# when input is [43, 56, 39, 50, 42, 10, 0, 19] the target: 47
# when input is [43, 56, 39, 50, 42, 10, 0, 19, 47] the target: 60
# when input is [43, 56, 39, 50, 42, 10, 0, 19, 47, 60] the target: 43
# when input is [43, 56, 39, 50, 42, 10, 0, 19, 47, 60, 43] the target: 1
# when input is [43, 56, 39, 50, 42, 10, 0, 19, 47, 60, 43, 1] the target: 61
# when input is [1] the target: 44
# when input is [1, 44] the target: 53
# when input is [1, 44, 53] the target: 52
# when input is [1, 44, 53, 52] the target: 42
# when input is [1, 44, 53, 52, 42] the target: 50
# when input is [1, 44, 53, 52, 42, 50] the target: 63
# when input is [1, 44, 53, 52, 42, 50, 63] the target: 1
# when input is [1, 44, 53, 52, 42, 50, 63, 1] the target: 45
# when input is [1, 44, 53, 52, 42, 50, 63, 1, 45] the target: 39
# when input is [1, 44, 53, 52, 42, 50, 63, 1, 45, 39] the target: 60
# when input is [1, 44, 53, 52, 42, 50, 63, 1, 45, 39, 60] the target: 43
# when input is [1, 44, 53, 52, 42, 50, 63, 1, 45, 39, 60, 43] the target: 1
# when input is [1] the target: 43
# when input is [1, 43] the target: 63
# when input is [1, 43, 63] the target: 43
# when input is [1, 43, 63, 43] the target: 57
# when input is [1, 43, 63, 43, 57] the target: 8
# when input is [1, 43, 63, 43, 57, 8] the target: 0
# when input is [1, 43, 63, 43, 57, 8, 0] the target: 32
# when input is [1, 43, 63, 43, 57, 8, 0, 32] the target: 46
# when input is [1, 43, 63, 43, 57, 8, 0, 32, 46] the target: 43
# when input is [1, 43, 63, 43, 57, 8, 0, 32, 46, 43] the target: 56
# when input is [1, 43, 63, 43, 57, 8, 0, 32, 46, 43, 56] the target: 43
# when input is [1, 43, 63, 43, 57, 8, 0, 32, 46, 43, 56, 43] the target: 44
# when input is [53] the target: 1
# when input is [53, 1] the target: 53
# when input is [53, 1, 53] the target: 59
# when input is [53, 1, 53, 59] the target: 56
# when input is [53, 1, 53, 59, 56] the target: 1
# when input is [53, 1, 53, 59, 56, 1] the target: 41
# when input is [53, 1, 53, 59, 56, 1, 41] the target: 53
# when input is [53, 1, 53, 59, 56, 1, 41, 53] the target: 51
# when input is [53, 1, 53, 59, 56, 1, 41, 53, 51] the target: 54
# when input is [53, 1, 53, 59, 56, 1, 41, 53, 51, 54] the target: 50
# when input is [53, 1, 53, 59, 56, 1, 41, 53, 51, 54, 50] the target: 53
# when input is [47, 57, 46, 1, 46, 43, 52, 41, 43, 1] the target: 58
# when input is [47, 57, 46, 1, 46, 43, 52, 41, 43, 1, 58] the target: 46
# when input is [47, 57, 46, 1, 46, 43, 52, 41, 43, 1, 58, 46] the target: 43
# when input is [1] the target: 51
# when input is [1, 51] the target: 63
# when input is [1, 51, 63] the target: 1
# when input is [1, 51, 63, 1] the target: 40
# when input is [1, 51, 63, 1, 40] the target: 56
# when input is [1, 51, 63, 1, 40, 56] the target: 39
# when input is [1, 51, 63, 1, 40, 56, 39] the target: 47
# when input is [1, 51, 63, 1, 40, 56, 39, 47] the target: 52
# when input is [1, 51, 63, 1, 40, 56, 39, 47, 52] the target: 6
# when input is [1, 51, 63, 1, 40, 56, 39, 47, 52, 6] the target: 1
# when input is [1, 51, 63, 1, 40, 56, 39, 47, 52, 6, 1] the target: 40
# when input is [1, 51, 63, 1, 40, 56, 39, 47, 52, 6, 1, 40] the target: 43
# when input is [54] the target: 39
# when input is [54, 39] the target: 56
# when input is [54, 39, 56] the target: 58
# when input is [54, 39, 56, 58] the target: 1
# when input is [54, 39, 56, 58, 1] the target: 58
# when input is [54, 39, 56, 58, 1, 58] the target: 46
# when input is [54, 39, 56, 58, 1, 58, 46] the target: 39
# when input is [54, 39, 56, 58, 1, 58, 46, 39] the target: 58
# when input is [54, 39, 56, 58, 1, 58, 46, 39, 58] the target: 1
# when input is [54, 39, 56, 58, 1, 58, 46, 39, 58, 1] the target: 47
# when input is [54, 39, 56, 58, 1, 58, 46, 39, 58, 1, 47] the target: 57
# when input is [54, 39, 56, 58, 1, 58, 46, 39, 58, 1, 47, 57] the target: 1
# when input is [46] the target: 1
# when input is [46, 1] the target: 46
# when input is [46, 1, 46] the target: 53
# when input is [46, 1, 46, 53] the target: 58
# when input is [46, 1, 46, 53, 58] the target: 1
# when input is [46, 1, 46, 53, 58, 1] the target: 63
# when input is [46, 1, 46, 53, 58, 1, 63] the target: 53
# when input is [46, 1, 46, 53, 58, 1, 63, 53] the target: 59
# when input is [46, 1, 46, 53, 58, 1, 63, 53, 59] the target: 58
# when input is [46, 1, 46, 53, 58, 1, 63, 53, 59, 58] the target: 46
# when input is [46, 1, 46, 53, 58, 1, 63, 53, 59, 58, 46] the target: 0
# when input is [46, 1, 46, 53, 58, 1, 63, 53, 59, 58, 46, 0] the target: 13
# when input is [56] the target: 1
# when input is [56, 1] the target: 52
# when input is [56, 1, 52] the target: 43
# when input is [56, 1, 52, 43] the target: 62
# when input is [56, 1, 52, 43, 62] the target: 58
# when input is [56, 1, 52, 43, 62, 58] the target: 1
# when input is [56, 1, 52, 43, 62, 58, 1] the target: 42
# when input is [56, 1, 52, 43, 62, 58, 1, 42] the target: 39
# when input is [56, 1, 52, 43, 62, 58, 1, 42, 39] the target: 63
# when input is [56, 1, 52, 43, 62, 58, 1, 42, 39, 63] the target: 6
# when input is [56, 1, 52, 43, 62, 58, 1, 42, 39, 63, 6] the target: 1
# when input is [56, 1, 52, 43, 62, 58, 1, 42, 39, 63, 6, 1] the target: 58
# when input is [1] the target: 61
# when input is [1, 61] the target: 46
# when input is [57, 1, 46, 43, 1, 42, 53, 52, 43] the target: 12
# when input is [57, 1, 46, 43, 1, 42, 53, 52, 43, 12] the target: 0
# when input is [57, 1, 46, 43, 1, 42, 53, 52, 43, 12, 0] the target: 0
# when input is [57, 1, 46, 43, 1, 42, 53, 52, 43, 12, 0, 0] the target: 28
# when input is [47] the target: 57
# when input is [47, 57] the target: 57
# when input is [47, 57, 57] the target: 1
# when input is [47, 57, 57, 1] the target: 39
# when input is [47, 57, 57, 1, 39] the target: 52
# when input is [47, 57, 57, 1, 39, 52] the target: 42
# when input is [47, 57, 57, 1, 39, 52, 42] the target: 1
# when input is [47, 57, 57, 1, 39, 52, 42, 1] the target: 48
# when input is [47, 57, 57, 1, 39, 52, 42, 1, 48] the target: 53
# when input is [47, 57, 57, 1, 39, 52, 42, 1, 48, 53] the target: 63
# when input is [47, 57, 57, 1, 39, 52, 42, 1, 48, 53, 63] the target: 8
# when input is [47, 57, 57, 1, 39, 52, 42, 1, 48, 53, 63, 8] the target: 0
# when input is [1] the target: 51
# when input is [1, 51] the target: 39
# when input is [1, 51, 39] the target: 56
# when input is [1, 51, 39, 56] the target: 6
# when input is [1, 51, 39, 56, 6] the target: 5
# when input is [1, 51, 39, 56, 6, 5] the target: 0
# when input is [1, 51, 39, 56, 6, 5, 0] the target: 55
# when input is [1, 51, 39, 56, 6, 5, 0, 55] the target: 59
# when input is [1, 51, 39, 56, 6, 5, 0, 55, 59] the target: 53
# when input is [1, 51, 39, 56, 6, 5, 0, 55, 59, 53] the target: 58
# when input is [1, 51, 39, 56, 6, 5, 0, 55, 59, 53, 58] the target: 46
# when input is [1, 51, 39, 56, 6, 5, 0, 55, 59, 53, 58, 46] the target: 1
# when input is [40] the target: 43
# when input is [40, 43] the target: 6
# when input is [40, 43, 6] the target: 1
# when input is [40, 43, 6, 1] the target: 58
# when input is [40, 43, 6, 1, 58] the target: 46
# when input is [40, 43, 6, 1, 58, 46] the target: 63
# when input is [40, 43, 6, 1, 58, 46, 63] the target: 1
# when input is [40, 43, 6, 1, 58, 46, 63, 1] the target: 51
# when input is [40, 43, 6, 1, 58, 46, 63, 1, 51] the target: 53
# when input is [40, 43, 6, 1, 58, 46, 63, 1, 51, 53] the target: 58
# when input is [40, 43, 6, 1, 58, 46, 63, 1, 51, 53, 58] the target: 46
# when input is [40, 43, 6, 1, 58, 46, 63, 1, 51, 53, 58, 46] the target: 43
# when input is [56] the target: 1
# when input is [56, 1] the target: 58
# when input is [56, 1, 58] the target: 56
# when input is [56, 1, 58, 56] the target: 59
# when input is [56, 1, 58, 56, 59] the target: 43
# when input is [56, 1, 58, 56, 59, 43] the target: 1
# when input is [56, 1, 58, 56, 59, 43, 1] the target: 58
# when input is [56, 1, 58, 56, 59, 43, 1, 58] the target: 46
# when input is [56, 1, 58, 56, 59, 43, 1, 58, 46] the target: 39
# when input is [56, 1, 58, 56, 59, 43, 1, 58, 46, 39] the target: 52
# when input is [56, 1, 58, 56, 59, 43, 1, 58, 46, 39, 52] the target: 1
# when input is [56, 1, 58, 56, 59, 43, 1, 58, 46, 39, 52, 1] the target: 63
# when input is [46] the target: 47
# when input is [46, 47] the target: 57
# when input is [46, 47, 57] the target: 1
# when input is [46, 47, 57, 1] the target: 57
# when input is [46, 47, 57, 1, 57] the target: 53
# when input is [46, 47, 57, 1, 57, 53] the target: 52
# when input is [46, 47, 57, 1, 57, 53, 52] the target: 8
# when input is [46, 47, 57, 1, 57, 53, 52, 8] the target: 0
# when input is [46, 47, 57, 1, 57, 53, 52, 8, 0] the target: 31
# when input is [46, 47, 57, 1, 57, 53, 52, 8, 0, 31] the target: 43
# when input is [46, 47, 57, 1, 57, 53, 52, 8, 0, 31, 43] the target: 43
# when input is [46, 47, 57, 1, 57, 53, 52, 8, 0, 31, 43, 43] the target: 1
# when input is [43] the target: 1
# when input is [43, 1] the target: 39
# when input is [43, 1, 39] the target: 1
# when input is [43, 1, 39, 1] the target: 45
# when input is [43, 1, 39, 1, 45] the target: 53
# when input is [43, 1, 39, 1, 45, 53] the target: 50
# when input is [43, 1, 39, 1, 45, 53, 50] the target: 42
# when input is [43, 1, 39, 1, 45, 53, 50, 42] the target: 43
# when input is [43, 1, 39, 1, 45, 53, 50, 42, 43] the target: 52
# when input is [43, 1, 39, 1, 45, 53, 50, 42, 43, 52] the target: 1
# when input is [43, 1, 39, 1, 45, 53, 50, 42, 43, 52, 1] the target: 57
# when input is [43, 1, 39, 1, 45, 53, 50, 42, 43, 52, 1, 57] the target: 43
# when input is [46] the target: 47
# when input is [46, 47] the target: 57
# when input is [46, 47, 57] the target: 1
# when input is [46, 47, 57, 1] the target: 44
# when input is [46, 47, 57, 1, 44] the target: 43
# when input is [46, 47, 57, 1, 44, 43] the target: 39
# when input is [46, 47, 57, 1, 44, 43, 39] the target: 56
# when input is [46, 47, 57, 1, 44, 43, 39, 56] the target: 44
# when input is [46, 47, 57, 1, 44, 43, 39, 56, 44] the target: 59
# when input is [46, 47, 57, 1, 44, 43, 39, 56, 44, 59] the target: 50
# when input is [46, 47, 57, 1, 44, 43, 39, 56, 44, 59, 50] the target: 1
# when input is [46, 47, 57, 1, 44, 43, 39, 56, 44, 59, 50, 1] the target: 42
# when input is [42] the target: 1
# when input is [42, 1] the target: 57
# when input is [42, 1, 57] the target: 58
# when input is [42, 1, 57, 58] the target: 39
# when input is [42, 1, 57, 58, 39] the target: 56
# when input is [42, 1, 57, 58, 39, 56] the target: 58
# when input is [42, 1, 57, 58, 39, 56, 58] the target: 50
# when input is [42, 1, 57, 58, 39, 56, 58, 50] the target: 43
# when input is [42, 1, 57, 58, 39, 56, 58, 50, 43] the target: 42
# when input is [42, 1, 57, 58, 39, 56, 58, 50, 43, 42] the target: 6
# when input is [42, 1, 57, 58, 39, 56, 58, 50, 43, 42, 6] the target: 1
# when input is [42, 1, 57, 58, 39, 56, 58, 50, 43, 42, 6, 1] the target: 61
# when input is [50] the target: 43
# when input is [50, 43] the target: 6
# when input is [50, 43, 6] the target: 0
# when input is [50, 43, 6, 0] the target: 13
# when input is [50, 43, 6, 0, 13] the target: 52
# when input is [50, 43, 6, 0, 13, 52] the target: 42
# when input is [50, 43, 6, 0, 13, 52, 42] the target: 1
# when input is [50, 43, 6, 0, 13, 52, 42, 1] the target: 57
# when input is [50, 43, 6, 0, 13, 52, 42, 1, 57] the target: 58
# when input is [50, 43, 6, 0, 13, 52, 42, 1, 57, 58] the target: 39
# when input is [50, 43, 6, 0, 13, 52, 42, 1, 57, 58, 39] the target: 56
# when input is [50, 43, 6, 0, 13, 52, 42, 1, 57, 58, 39, 56] the target: 58
# when input is [56] the target: 53
# when input is [56, 53] the target: 44
# when input is [56, 53, 44] the target: 43
# when input is [56, 53, 44, 43] the target: 57
# when input is [56, 53, 44, 43, 57] the target: 57
# when input is [56, 53, 44, 43, 57, 57] the target: 6
# when input is [56, 53, 44, 43, 57, 57, 6] the target: 1
# when input is [56, 53, 44, 43, 57, 57, 6, 1] the target: 21
# when input is [56, 53, 44, 43, 57, 57, 6, 1, 21] the target: 1
# when input is [56, 53, 44, 43, 57, 57, 6, 1, 21, 1] the target: 61
# when input is [56, 53, 44, 43, 57, 57, 6, 1, 21, 1, 61] the target: 47
# when input is [56, 53, 44, 43, 57, 57, 6, 1, 21, 1, 61, 47] the target: 50

# %% [markdown]
# ## Bigram Language Model

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F
torch.manual_seed(1337)

@torch.no_grad()
def estimate_loss(): # to reduce noise of the losses
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class BigramLanguageModel(nn.Module):

    def __init__(self, vocab_size):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, vocab_size)

    def forward(self, idx, targets=None):
        # idx and targets are both (B,T) tensor of integers
        logits = self.token_embedding_table(idx) # (B,T,C)
        
        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C) # Logits are the outputs of a neural network before the activation function is applied.
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss
    
    def generate(self, idx, max_new_tokens): # given a idx
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # get the predictions
            logits, loss = self(idx)  # self.forward()
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel(char_size)
model.to(device)
logits, loss = model(xb, yb)
print(logits.shape)
print(loss)

print(tokenizer.decode_combined(model.generate(idx = torch.ones((1, 7), dtype=torch.long), max_new_tokens=100)[0].tolist()))
# Out:
# torch.Size([384, 65])
# tensor(4.7389, device='cuda:0', grad_fn=<NllLossBackward0>)
#        qfCxbDkRZkNwc.wj,ZTxO-On-y$WK
# baqPe?kMBFeA$G:XZSGgO-3cjMGd?gLhaGhX'YVX3tpgfNuwq&$WWv.tbaF :X3!FHaGeN

# %% [markdown]
# ## Train Model

# %%
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# %%
# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
# context = torch.tensor([tokenizer.encode_combined(list("Hello There "))], dtype=torch.long, device=device)
print(tokenizer.decode_combined(model.generate(context, max_new_tokens=100)[0].tolist()))
