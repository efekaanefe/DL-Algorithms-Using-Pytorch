# %%
# Props to this sensei
# https://www.youtube.com/watch?v=kCc8FmEb1nY&list=PLAqhIrjkxbuWI23v9cThsA9GvCAUhRvKZ&index=8

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torch.autograd import Variable
import torch.nn.functional as F

from tqdm import tqdm # progress bar

# %% [markdown]
# ## Hyper-parameters

# %%
text_file = "tiny-shakespeare.txt"
batch_size = 32 # how many independent sequences will we process in parallel?
block_size = 256 # what is the maximum context length for predictions?
max_iters = 5000 # total # of iterations for different batches
learning_rate = 4e-4
n_embd = 64 # embedding dimension, affects how unique a token(char) can be represented from the others
n_head = 4 # number of heads we'd like
n_layer = 4 # number of decoder blocks
dropout = 0.2 # dropout probability for the embedding layer, residual connections and attention weights

# printing related variables for training
eval_interval = 10
eval_iters = 200

device = ("cuda" if torch.cuda.is_available() else "mps"
          if torch.backends.mps.is_available() else "cpu")
print(f"Using {device} device")
torch.set_default_device(device)
# Out:
# Using cuda device

# %% [markdown]
# ## Reading Data

# %%
# read file
with open(text_file, "r") as f:
    text = f.read()
text[:100]
# Out:
# 'First Citizen:\nBefore we proceed any further, hear me speak.\n\nAll:\nSpeak, speak.\n\nFirst Citizen:\nYou'

# %%
vocab_list = sorted(list(set(text))) # more like a unique_char_list
vocab_size = len(vocab_list)

print(f"All the characters in the text: {''.join(vocab_list)}")
print(f"Length of the characters: {vocab_size}")
# Out:
# All the characters in the text:
#  !$&',-.3:;?ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz
# Length of the characters: 65

# %% [markdown]
# ## Tokenizer (character based, index/ascii)

# %%
class MyTokenizer:
    def __init__(self):
        self.char_to_index = None
        self.index_to_char = None

    def fit(self, char_list):  
        self.char_to_index = {char: idx for idx, char in enumerate(char_list)}
        self.index_to_char = {idx: char for char, idx in self.char_to_index.items()}

    def encode_index(self, input_str):
        return [self.char_to_index[char] for char in input_str]

    def decode_index(self, encoded_list):
        return ''.join([self.index_to_char[idx] for idx in encoded_list])

    @staticmethod
    def ascii_tokenizer(char):
        return ord(char)

    @staticmethod
    def ascii_decoder(ascii_value):
        return chr(ascii_value)

    def encode_combined(self, input_str, use_ascii=False):
        if use_ascii:
            return [self.ascii_tokenizer(char) for char in input_str]
        else:
            return self.encode_index(input_str)

    def decode_combined(self, encoded_list, use_ascii=False):
        if use_ascii:
            return ''.join([self.ascii_decoder(ascii_value) for ascii_value in encoded_list])
        else:
            return self.decode_index(encoded_list)

# %%
# Example usage:
tokenizer = MyTokenizer()
tokenizer.fit(vocab_list)

input_str = "Hello there"
encoded_list_ascii = tokenizer.encode_combined(input_str, use_ascii=True)
decoded_str_ascii = tokenizer.decode_combined(encoded_list_ascii, use_ascii=True)

encoded_list_index = tokenizer.encode_combined(input_str, use_ascii=True)
decoded_str_index = tokenizer.decode_combined(encoded_list_index, use_ascii=True)

print("Original String:", input_str)
print("Encoded List (ASCII):", encoded_list_ascii)
print("Decoded String (ASCII):", decoded_str_ascii)

print("Encoded List (Index):", encoded_list_index)
print("Decoded String (Index):", decoded_str_index)
# Out:
# Original String: Hello there
# Encoded List (ASCII): [72, 101, 108, 108, 111, 32, 116, 104, 101, 114, 101]
# Decoded String (ASCII): Hello there
# Encoded List (Index): [72, 101, 108, 108, 111, 32, 116, 104, 101, 114, 101]
# Decoded String (Index): Hello there

# %% [markdown]
# ## Batching

# %%
# Encode all the data and split into train and val
encoded_data = torch.tensor(tokenizer.encode_combined(text))
n = int( 0.9 * len(encoded_data))

train_data = encoded_data[:n]
val_data = encoded_data[n:]

train_data[:block_size + 1]
# Out:
# tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43, 44,
#         53, 56, 43,  1, 61, 43,  1, 54, 56, 53, 41, 43, 43, 42,  1, 39, 52, 63,
#          1, 44, 59, 56, 58, 46, 43, 56,  6,  1, 46, 43, 39, 56,  1, 51, 43,  1,
#         57, 54, 43, 39, 49,  8,  0,  0, 13, 50, 50, 10,  0, 31, 54, 43, 39, 49,
#          6,  1, 57, 54, 43, 39, 49,  8,  0,  0, 18, 47, 56, 57, 58,  1, 15, 47,
#         58, 47, 64, 43, 52, 10,  0, 37, 53, 59,  1, 39, 56, 43,  1, 39, 50, 50,
#          1, 56, 43, 57, 53, 50, 60, 43, 42,  1, 56, 39, 58, 46, 43, 56,  1, 58,
#         53,  1, 42, 47, 43,  1, 58, 46, 39, 52,  1, 58, 53,  1, 44, 39, 51, 47,
#         57, 46, 12,  0,  0, 13, 50, 50, 10,  0, 30, 43, 57, 53, 50, 60, 43, 42,
#          8,  1, 56, 43, 57, 53, 50, 60, 43, 42,  8,  0,  0, 18, 47, 56, 57, 58,
#          1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 18, 47, 56, 57, 58,  6,  1, 63,
#         53, 59,  1, 49, 52, 53, 61,  1, 15, 39, 47, 59, 57,  1, 25, 39, 56, 41,
#         47, 59, 57,  1, 47, 57,  1, 41, 46, 47, 43, 44,  1, 43, 52, 43, 51, 63,
#          1, 58, 53,  1, 58, 46, 43,  1, 54, 43, 53, 54, 50, 43,  8,  0,  0, 13,
#         50, 50, 10,  0, 35], device='cuda:0')

# %%
x = train_data[0:block_size]
y = train_data[1:block_size+1]

for t in range(block_size):
    context = x[:t+1]
    target = y[t]
    
    print(f"when input is {context} the target: {target}")
# Out:
# when input is tensor([18], device='cuda:0') the target: 47
# when input is tensor([18, 47], device='cuda:0') the target: 56
# when input is tensor([18, 47, 56], device='cuda:0') the target: 57
# when input is tensor([18, 47, 56, 57], device='cuda:0') the target: 58
# when input is tensor([18, 47, 56, 57, 58], device='cuda:0') the target: 1
# when input is tensor([18, 47, 56, 57, 58,  1], device='cuda:0') the target: 15
# when input is tensor([18, 47, 56, 57, 58,  1, 15], device='cuda:0') the target: 47
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47], device='cuda:0') the target: 58
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58], device='cuda:0') the target: 47
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47], device='cuda:0') the target: 64
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64], device='cuda:0') the target: 43
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43], device='cuda:0') the target: 52
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52], device='cuda:0') the target: 10
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10],
#        device='cuda:0') the target: 0
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0],
#        device='cuda:0') the target: 14
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14],
#        device='cuda:0') the target: 43
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43],
#        device='cuda:0') the target: 44
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43, 44],
#        device='cuda:0') the target: 53
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43, 44,
#         53], device='cuda:0') the target: 56
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43, 44,
#         53, 56], device='cuda:0') the target: 43
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43, 44,
#         53, 56, 43], device='cuda:0') the target: 1
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43, 44,
#         53, 56, 43,  1], device='cuda:0') the target: 61
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43, 44,
#         53, 56, 43,  1, 61], device='cuda:0') the target: 43
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43, 44,
#         53, 56, 43,  1, 61, 43], device='cuda:0') the target: 1
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43, 44,
#         53, 56, 43,  1, 61, 43,  1], device='cuda:0') the target: 54
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43, 44,
#         53, 56, 43,  1, 61, 43,  1, 54], device='cuda:0') the target: 56
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43, 44,
#         53, 56, 43,  1, 61, 43,  1, 54, 56], device='cuda:0') the target: 53
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43, 44,
#         53, 56, 43,  1, 61, 43,  1, 54, 56, 53], device='cuda:0') the target: 41
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43, 44,
#         53, 56, 43,  1, 61, 43,  1, 54, 56, 53, 41], device='cuda:0') the target: 43
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43, 44,
#         53, 56, 43,  1, 61, 43,  1, 54, 56, 53, 41, 43], device='cuda:0') the target: 43
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43, 44,
#         53, 56, 43,  1, 61, 43,  1, 54, 56, 53, 41, 43, 43], device='cuda:0') the target: 42
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43, 44,
#         53, 56, 43,  1, 61, 43,  1, 54, 56, 53, 41, 43, 43, 42],
#        device='cuda:0') the target: 1
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43, 44,
#         53, 56, 43,  1, 61, 43,  1, 54, 56, 53, 41, 43, 43, 42,  1],
#        device='cuda:0') the target: 39
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43, 44,
#         53, 56, 43,  1, 61, 43,  1, 54, 56, 53, 41, 43, 43, 42,  1, 39],
#        device='cuda:0') the target: 52
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43, 44,
#         53, 56, 43,  1, 61, 43,  1, 54, 56, 53, 41, 43, 43, 42,  1, 39, 52],
#        device='cuda:0') the target: 63
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43, 44,
#         53, 56, 43,  1, 61, 43,  1, 54, 56, 53, 41, 43, 43, 42,  1, 39, 52, 63],
#        device='cuda:0') the target: 1
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43, 44,
#         53, 56, 43,  1, 61, 43,  1, 54, 56, 53, 41, 43, 43, 42,  1, 39, 52, 63,
#          1], device='cuda:0') the target: 44
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43, 44,
#         53, 56, 43,  1, 61, 43,  1, 54, 56, 53, 41, 43, 43, 42,  1, 39, 52, 63,
#          1, 44], device='cuda:0') the target: 59
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43, 44,
#         53, 56, 43,  1, 61, 43,  1, 54, 56, 53, 41, 43, 43, 42,  1, 39, 52, 63,
#          1, 44, 59], device='cuda:0') the target: 56
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43, 44,
#         53, 56, 43,  1, 61, 43,  1, 54, 56, 53, 41, 43, 43, 42,  1, 39, 52, 63,
#          1, 44, 59, 56], device='cuda:0') the target: 58
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43, 44,
#         53, 56, 43,  1, 61, 43,  1, 54, 56, 53, 41, 43, 43, 42,  1, 39, 52, 63,
#          1, 44, 59, 56, 58], device='cuda:0') the target: 46
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43, 44,
#         53, 56, 43,  1, 61, 43,  1, 54, 56, 53, 41, 43, 43, 42,  1, 39, 52, 63,
#          1, 44, 59, 56, 58, 46], device='cuda:0') the target: 43
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43, 44,
#         53, 56, 43,  1, 61, 43,  1, 54, 56, 53, 41, 43, 43, 42,  1, 39, 52, 63,
#          1, 44, 59, 56, 58, 46, 43], device='cuda:0') the target: 56
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43, 44,
#         53, 56, 43,  1, 61, 43,  1, 54, 56, 53, 41, 43, 43, 42,  1, 39, 52, 63,
#          1, 44, 59, 56, 58, 46, 43, 56], device='cuda:0') the target: 6
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43, 44,
#         53, 56, 43,  1, 61, 43,  1, 54, 56, 53, 41, 43, 43, 42,  1, 39, 52, 63,
#          1, 44, 59, 56, 58, 46, 43, 56,  6], device='cuda:0') the target: 1
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43, 44,
#         53, 56, 43,  1, 61, 43,  1, 54, 56, 53, 41, 43, 43, 42,  1, 39, 52, 63,
#          1, 44, 59, 56, 58, 46, 43, 56,  6,  1], device='cuda:0') the target: 46
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43, 44,
#         53, 56, 43,  1, 61, 43,  1, 54, 56, 53, 41, 43, 43, 42,  1, 39, 52, 63,
#          1, 44, 59, 56, 58, 46, 43, 56,  6,  1, 46], device='cuda:0') the target: 43
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43, 44,
#         53, 56, 43,  1, 61, 43,  1, 54, 56, 53, 41, 43, 43, 42,  1, 39, 52, 63,
#          1, 44, 59, 56, 58, 46, 43, 56,  6,  1, 46, 43], device='cuda:0') the target: 39
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43, 44,
#         53, 56, 43,  1, 61, 43,  1, 54, 56, 53, 41, 43, 43, 42,  1, 39, 52, 63,
#          1, 44, 59, 56, 58, 46, 43, 56,  6,  1, 46, 43, 39], device='cuda:0') the target: 56
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43, 44,
#         53, 56, 43,  1, 61, 43,  1, 54, 56, 53, 41, 43, 43, 42,  1, 39, 52, 63,
#          1, 44, 59, 56, 58, 46, 43, 56,  6,  1, 46, 43, 39, 56],
#        device='cuda:0') the target: 1
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43, 44,
#         53, 56, 43,  1, 61, 43,  1, 54, 56, 53, 41, 43, 43, 42,  1, 39, 52, 63,
#          1, 44, 59, 56, 58, 46, 43, 56,  6,  1, 46, 43, 39, 56,  1],
#        device='cuda:0') the target: 51
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43, 44,
#         53, 56, 43,  1, 61, 43,  1, 54, 56, 53, 41, 43, 43, 42,  1, 39, 52, 63,
#          1, 44, 59, 56, 58, 46, 43, 56,  6,  1, 46, 43, 39, 56,  1, 51],
#        device='cuda:0') the target: 43
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43, 44,
#         53, 56, 43,  1, 61, 43,  1, 54, 56, 53, 41, 43, 43, 42,  1, 39, 52, 63,
#          1, 44, 59, 56, 58, 46, 43, 56,  6,  1, 46, 43, 39, 56,  1, 51, 43],
#        device='cuda:0') the target: 1
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43, 44,
#         53, 56, 43,  1, 61, 43,  1, 54, 56, 53, 41, 43, 43, 42,  1, 39, 52, 63,
#          1, 44, 59, 56, 58, 46, 43, 56,  6,  1, 46, 43, 39, 56,  1, 51, 43,  
    data = train_data if split == "train" else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,)) # tensor of random indexes (batch_size, )
    x = torch.stack([data[i:i+block_size] for i in ix]) # from the random index go until block_size, for all random indexes
    y = torch.stack([data[i+1:i+block_size+1] for i in ix]) # from the random index+1 go until block_size+1, for all random indexes
    return x,y 

xb, yb = get_batch("train") # xb -> input to the transformer
print("inputs: ")
print(xb.shape)
print(xb)

print("targets: ")
print(yb.shape)
print(yb)

for b in range(batch_size): # batch dimension
    for t in range(block_size): # time dimension
        context = xb[b, :t+1]
        target = yb[b,t]
        # print(f"when input is {context.tolist()} the target: {target}")

# %% [markdown]
# ## GPT (char level)

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F
torch.manual_seed(1337)

@torch.no_grad()
def estimate_loss(): # to reduce noise of the losses
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out


class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out


class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)


class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x


class GPT(nn.Module):
    
    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step, makes it bigram
            logits = logits[:, -1, :] # becomes (B, C) 
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = GPT()
model.to(device)
logits, loss = model(xb, yb)
print(logits.shape)
print(loss)

print(tokenizer.decode_combined(model.generate(idx = torch.zeros((1, 1), dtype=torch.long), max_new_tokens=100)[0].tolist()))
# Out:
# torch.Size([8192, 65])
# tensor(4.3291, device='cuda:0', grad_fn=<NllLossBackward0>)
#
# sxcmEnsn3x$OoTwcskQ-BLUitb3;HCIHWpOlZBYWu-'Z'jsf-&DrV;RfK$Xr
# mqXudue'hvfmfygv3QrgANJGoGaDzJb'mg.,E?R

# %% [markdown]
# ## Train Model

# %%
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()
# Out:
# step 0: train loss 4.3362, val loss 4.3351
# step 10: train loss 3.7072, val loss 3.7244
# step 20: train loss 3.4545, val loss 3.4856
# step 30: train loss 3.3404, val loss 3.3712
# step 40: train loss 3.2660, val loss 3.2993
# step 50: train loss 3.1885, val loss 3.2234
# step 60: train loss 3.1060, val loss 3.1424
# step 70: train loss 3.0410, val loss 3.0763
# step 80: train loss 2.9788, val loss 3.0110
# step 90: train loss 2.9283, val loss 2.9590
# step 100: train loss 2.8804, val loss 2.9079
# step 110: train loss 2.8431, val loss 2.8669
# step 120: train loss 2.8065, val loss 2.8271
# step 130: train loss 2.7793, val loss 2.7964
# step 140: train loss 2.7524, val loss 2.7684
# step 150: train loss 2.7312, val loss 2.7444
# step 160: train loss 2.7083, val loss 2.7237
# step 170: train loss 2.6932, val loss 2.7043
# step 180: train loss 2.6740, val loss 2.6897
# step 190: train loss 2.6592, val loss 2.6732
# step 200: train loss 2.6462, val loss 2.6588
# step 210: train loss 2.6367, val loss 2.6480
# step 220: train loss 2.6252, val loss 2.6356
# step 230: train loss 2.6153, val loss 2.6260
# step 240: train loss 2.6053, val loss 2.6174
# step 250: train loss 2.6003, val loss 2.6083
# step 260: train loss 2.5951, val loss 2.6014
# step 270: train loss 2.5856, val loss 2.5941
# step 280: train loss 2.5789, val loss 2.5879
# step 290: train loss 2.5730, val loss 2.5812
# step 300: train loss 2.5694, val loss 2.5738
# step 310: train loss 2.5657, val loss 2.5748
# step 320: train loss 2.5599, val loss 2.5700
# step 330: train loss 2.5574, val loss 2.5636
# step 340: train loss 2.5515, val loss 2.5588
# step 350: train loss 2.5465, val loss 2.5518
# step 360: train loss 2.5440, val loss 2.5521
# step 370: train loss 2.5417, val loss 2.5476
# step 380: train loss 2.5407, val loss 2.5449
# step 390: train loss 2.5355, val loss 2.5458
# step 400: train loss 2.5334, val loss 2.5368
# step 410: train loss 2.5286, val loss 2.5389
# step 420: train loss 2.5249, val loss 2.5364
# step 430: train loss 2.5249, val loss 2.5318
# step 440: train loss 2.5219, val loss 2.5289
# step 450: train loss 2.5181, val loss 2.5276
# step 460: train loss 2.5180, val loss 2.5252
# step 470: train loss 2.5125, val loss 2.5253
# step 480: train loss 2.5129, val loss 2.5241
# step 490: train loss 2.5124, val loss 2.5227
# step 500: train loss 2.5088, val loss 2.5218
# step 510: train loss 2.5060, val loss 2.5141
# step 520: train loss 2.5055, val loss 2.5097
# step 530: train loss 2.5030, val loss 2.5130
# step 540: train loss 2.5011, val loss 2.5106
# step 550: train loss 2.4992, val loss 2.5105
# step 560: train loss 2.4976, val loss 2.5102
# step 570: train loss 2.4967, val loss 2.5069
# step 580: train loss 2.4965, val loss 2.5030
# step 590: train loss 2.4921, val loss 2.5017
# step 600: train loss 2.4915, val loss 2.4972
# step 610: train loss 2.4884, val loss 2.5012
# step 620: train loss 2.4892, val loss 2.4983
# step 630: train loss 2.4865, val loss 2.4963
# step 640: train loss 2.4854, val loss 2.4957
# step 650: train loss 2.4846, val loss 2.4973
# step 660: train loss 2.4829, val loss 2.4941
# step 670: train loss 2.4800, val loss 2.4902
# step 680: train loss 2.4786, val loss 2.4919
# step 690: train loss 2.4798, val loss 2.4905
# step 700: train loss 2.4783, val loss 2.4865
# step 710: train loss 2.4741, val loss 2.4880
# step 720: train loss 2.4730, val loss 2.4856
# step 730: train loss 2.4731, val loss 2.4829
# step 740: train loss 2.4720, val loss 2.4835
# step 750: train loss 2.4701, val loss 2.4802
# step 760: train loss 2.4702, val loss 2.4773
# step 770: train loss 2.4659, val loss 2.4799
# step 780: train loss 2.4637, val loss 2.4807
# step 790: train loss 2.4627, val loss 2.4780
# step 800: train loss 2.4633, val loss 2.4757
# step 810: train loss 2.4609, val loss 2.4762
# step 820: train loss 2.4606, val loss 2.4704
# step 830: train loss 2.4594, val loss 2.4715
# step 840: train loss 2.4603, val loss 2.4705
# step 850: train loss 2.4578, val loss 2.4668
# step 860: train loss 2.4555, val loss 2.4677
# step 870: train loss 2.4567, val loss 2.4724
# step 880: train loss 2.4543, val loss 2.4680
# step 890: train loss 2.4546, val loss 2.4680
# step 900: train loss 2.4506, val loss 2.4651
# step 910: train loss 2.4512, val loss 2.4662
# step 920: train loss 2.4469, val loss 2.4603
# step 930: train loss 2.4480, val loss 2.4628
# step 940: train loss 2.4467, val loss 2.4615
# step 950: train loss 2.4455, val loss 2.4586
# step 960: train loss 2.4464, val loss 2.4615
# step 970: train loss 2.4437, val loss 2.4603
# step 980: train loss 2.4450, val loss 2.4623
# step 990: train loss 2.4420, val loss 2.4583
# step 1000: train loss 2.4407, val loss 2.4541
# step 1010: train loss 2.4417, val loss 2.4582
# step 1020: train loss 2.4390, val loss 2.4529
# step 1030: train loss 2.4392, val loss 2.4525
# step 1040: train loss 2.4364, val loss 2.4508
# step 1050: train loss 2.4350, val loss 2.4570
# step 1060: train loss 2.4352, val loss 2.4503
# step 1070: train loss 2.4365, val loss 2.4477
# step 1080: train loss 2.4338, val loss 2.4457
# step 1090: train loss 2.4314, val loss 2.4475
# step 1100: train loss 2.4293, val loss 2.4406
# step 1110: train loss 2.4295, val loss 2.4437
# step 1120: train loss 2.4264, val loss 2.4438
# step 1130: train loss 2.4261, val loss 2.4403
# step 1140: train loss 2.4257, val loss 2.4398
# step 1150: train loss 2.4231, val loss 2.4369
# step 1160: train loss 2.4223, val loss 2.4319
# step 1170: train loss 2.4258, val loss 2.4351
# step 1180: train loss 2.4205, val loss 2.4353
# step 1190: train loss 2.4194, val loss 2.4343
# step 1200: train loss 2.4177, val loss 2.4307
# step 1210: train loss 2.4144, val loss 2.4273
# step 1220: train loss 2.4153, val loss 2.4286
# step 1230: train loss 2.4148, val loss 2.4284
# step 1240: train loss 2.4136, val loss 2.4273
# step 1250: train loss 2.4109, val loss 2.4257
# step 1260: train loss 2.4102, val loss 2.4226
# step 1270: train loss 2.4082, val loss 2.4202
# step 1280: train loss 2.4089, val loss 2.4199
# step 1290: train loss 2.4092, val loss 2.4211
# step 1300: train loss 2.4042, val loss 2.4194
# step 1310: train loss 2.4032, val loss 2.4168
# step 1320: train loss 2.4004, val loss 2.4183
# step 1330: train loss 2.4005, val loss 2.4193
# step 1340: train loss 2.3999, val loss 2.4161
# step 1350: train loss 2.3974, val loss 2.4163
# step 1360: train loss 2.3970, val loss 2.4128
# step 1370: train loss 2.3961, val loss 2.4098
# step 1380: train loss 2.3970, val loss 2.4099
# step 1390: train loss 2.3930, val loss 2.4089
# step 1400: train loss 2.3912, val loss 2.4107
# step 1410: train loss 2.3873, val loss 2.4015
# step 1420: train loss 2.3873, val loss 2.3970
# step 1430: train loss 2.3896, val loss 2.3995
# step 1440: train loss 2.3868, val loss 2.4026
# step 1450: train loss 2.3864, val loss 2.3980
# step 1460: train loss 2.3816, val loss 2.3947
# step 1470: train loss 2.3789, val loss 2.3988
# step 1480: train loss 2.3788, val loss 2.3927
# step 1490: train loss 2.3750, val loss 2.3919
# step 1500: train loss 2.3752, val loss 2.3927
# step 1510: train loss 2.3721, val loss 2.3879
# step 1520: train loss 2.3709, val loss 2.3867
# step 1530: train loss 2.3679, val loss 2.3862
# step 1540: train loss 2.3695, val loss 2.3839
# step 1550: train loss 2.3686, val loss 2.3851
# step 1560: train loss 2.3668, val loss 2.3844
# step 1570: train loss 2.3639, val loss 2.3812
# step 1580: train loss 2.3632, val loss 2.3807
# step 1590: train loss 2.3582, val loss 2.3777
# step 1600: train loss 2.3540, val loss 2.3738
# step 1610: train loss 2.3523, val loss 2.3743
# step 1620: train loss 2.3546, val loss 2.3724
# step 1630: train loss 2.3506, val loss 2.3682
# step 1640: train loss 2.3501, val loss 2.3690
# step 1650: train loss 2.3473, val loss 2.3625
# step 1660: train loss 2.3470, val loss 2.3611
# step 1670: train loss 2.3413, val loss 2.3625
# step 1680: train loss 2.3418, val loss 2.3635
# step 1690: train loss 2.3417, val loss 2.3590
# step 1700: train loss 2.3375, val loss 2.3601
# step 1710: train loss 2.3388, val loss 2.3538
# step 1720: train loss 2.3359, val loss 2.3589
# step 1730: train loss 2.3319, val loss 2.3559
# step 1740: train loss 2.3314, val loss 2.3510
# step 1750: train loss 2.3316, val loss 2.3471
# step 1760: train loss 2.3283, val loss 2.3506
# step 1770: train loss 2.3250, val loss 2.3431
# step 1780: train loss 2.3275, val loss 2.3452
# step 1790: train loss 2.3224, val loss 2.3439
# step 1800: train loss 2.3201, val loss 2.3412
# step 1810: train loss 2.3169, val loss 2.3407
# step 1820: train loss 2.3145, val loss 2.3354
# step 1830: train loss 2.3116, val loss 2.3311
# step 1840: train loss 2.3144, val loss 2.3386
# step 1850: train loss 2.3130, val loss 2.3350
# step 1860: train loss 2.3098, val loss 2.3338
# step 1870: train loss 2.3066, val loss 2.3278
# step 1880: train loss 2.3054, val loss 2.3284
# step 1890: train loss 2.3023, val loss 2.3257
# step 1900: train loss 2.3034, val loss 2.3246
# step 1910: train loss 2.2973, val loss 2.3188
# step 1920: train loss 2.2978, val loss 2.3216
# step 1930: train loss 2.2978, val loss 2.3216
# step 1940: train loss 2.2913, val loss 2.3154
# step 1950: train loss 2.2936, val loss 2.3192
# step 1960: train loss 2.2901, val loss 2.3166
# step 1970: train loss 2.2879, val loss 2.3174
# step 1980: train loss 2.2883, val loss 2.3141
# step 1990: train loss 2.2851, val loss 2.3089
# step 2000: train loss 2.2796, val loss 2.3057
# step 2010: train loss 2.2813, val loss 2.3096
# step 2020: train loss 2.2790, val loss 2.3078
# step 2030: train loss 2.2822, val loss 2.3053
# step 2040: train loss 2.2777, val loss 2.2984
# step 2050: train loss 2.2740, val loss 2.3039
# step 2060: train loss 2.2734, val loss 2.2980
# step 2070: train loss 2.2725, val loss 2.3004
# step 2080: train loss 2.2681, val loss 2.2975
# step 2090: train loss 2.2692, val loss 2.2945
# step 2100: train loss 2.2671, val loss 2.2917
# step 2110: train loss 2.2671, val loss 2.2890
# step 2120: train loss 2.2591, val loss 2.2895
# step 2130: train loss 2.2669, val loss 2.2903
# step 2140: train loss 2.2614, val loss 2.2871
# step 2150: train loss 2.2578, val loss 2.2856
# step 2160: train loss 2.2584, val loss 2.2894
# step 2170: train loss 2.2558, val loss 2.2838
# step 2180: train loss 2.2503, val loss 2.2783
# step 2190: train loss 2.2528, val loss 2.2805
# step 2200: train loss 2.2469, val loss 2.2747
# step 2210: train loss 2.2496, val loss 2.2715
# step 2220: train loss 2.2473, val loss 2.2763
# step 2230: train loss 2.2439, val loss 2.2736
# step 2240: train loss 2.2433, val loss 2.2718
# step 2250: train loss 2.2423, val loss 2.2714
# step 2260: train loss 2.2392, val loss 2.2630
# step 2270: train loss 2.2385, val loss 2.2682
# step 2280: train loss 2.2411, val loss 2.2639
# step 2290: train loss 2.2331, val loss 2.2609
# step 2300: train loss 2.2335, val loss 2.2629
# step 2310: train loss 2.2300, val loss 2.2611
# step 2320: train loss 2.2286, val loss 2.2613
# step 2330: train loss 2.2270, val loss 2.2561
# step 2340: train loss 2.2280, val loss 2.2593
# step 2350: train loss 2.2272, val loss 2.2560
# step 2360: train loss 2.2244, val loss 2.2601
# step 2370: train loss 2.2250, val loss 2.2561
# step 2380: train loss 2.2231, val loss 2.2544
# step 2390: train loss 2.2236, val loss 2.2541
# step 2400: train loss 2.2181, val loss 2.2497
# step 2410: train loss 2.2204, val loss 2.2520
# step 2420: train loss 2.2209, val loss 2.2527
# step 2430: train loss 2.2136, val loss 2.2443
# step 2440: train loss 2.2176, val loss 2.2494
# step 2450: train loss 2.2143, val loss 2.2479
# step 2460: train loss 2.2079, val loss 2.2429
# step 2470: train loss 2.2087, val loss 2.2439
# step 2480: train loss 2.2040, val loss 2.2422
# step 2490: train loss 2.2033, val loss 2.2423
# step 2500: train loss 2.2076, val loss 2.2447
# step 2510: train loss 2.2036, val loss 2.2384
# step 2520: train loss 2.2055, val loss 2.2418
# step 2530: train loss 2.2031, val loss 2.2359
# step 2540: train loss 2.2015, val loss 2.2338
# step 2550: train loss 2.1969, val loss 2.2379
# step 2560: train loss 2.1995, val loss 2.2337
# step 2570: train loss 2.1986, val loss 2.2384
# step 2580: train loss 2.1960, val loss 2.2309
# step 2590: train loss 2.1948, val loss 2.2283
# step 2600: train loss 2.1919, val loss 2.2282
# step 2610: train loss 2.1899, val loss 2.2230
# step 2620: train loss 2.1878, val loss 2.2243
# step 2630: train loss 2.1893, val loss 2.2255
# step 2640: train loss 2.1884, val loss 2.2219
# step 2650: train loss 2.1851, val loss 2.2213
# step 2660: train loss 2.1839, val loss 2.2199
# step 2670: train loss 2.1819, val loss 2.2158
# step 2680: train loss 2.1826, val loss 2.2130
# step 2690: train loss 2.1809, val loss 2.2188
# step 2700: train loss 2.1758, val loss 2.2147
# step 2710: train loss 2.1751, val loss 2.2184
# step 2720: train loss 2.1757, val loss 2.2102
# step 2730: train loss 2.1713, val loss 2.2109
# step 2740: train loss 2.1734, val loss 2.2126
# step 2750: train loss 2.1731, val loss 2.2126
# step 2760: train loss 2.1732, val loss 2.2109
# step 2770: train loss 2.1703, val loss 2.2126
# step 2780: train loss 2.1693, val loss 2.2048
# step 2790: train loss 2.1701, val loss 2.2101
# step 2800: train loss 2.1641, val loss 2.2048
# step 2810: train loss 2.1649, val loss 2.2052
# step 2820: train loss 2.1654, val loss 2.2049
# step 2830: train loss 2.1622, val loss 2.2024
# step 2840: train loss 2.1603, val loss 2.2036
# step 2850: train loss 2.1619, val loss 2.2036
# step 2860: train loss 2.1577, val loss 2.1988
# step 2870: train loss 2.1559, val loss 2.1947
# step 2880: train loss 2.1553, val loss 2.1960
# step 2890: train loss 2.1570, val loss 2.1958
# step 2900: train loss 2.1514, val loss 2.1922
# step 2910: train loss 2.1523, val loss 2.1981
# step 2920: train loss 2.1515, val loss 2.1952
# step 2930: train loss 2.1503, val loss 2.1911
# step 2940: train loss 2.1500, val loss 2.1936
# step 2950: train loss 2.1474, val loss 2.1879
# step 2960: train loss 2.1490, val loss 2.1891
# step 2970: train loss 2.1450, val loss 2.1881
# step 2980: train loss 2.1460, val loss 2.1897
# step 2990: train loss 2.1424, val loss 2.1881
# step 3000: train loss 2.1467, val loss 2.1827
# step 3010: train loss 2.1421, val loss 2.1816
# step 3020: train loss 2.1398, val loss 2.1831
# step 3030: train loss 2.1350, val loss 2.1770
# step 3040: train loss 2.1368, val loss 2.1811
# step 3050: train loss 2.1330, val loss 2.1793
# step 3060: train loss 2.1326, val loss 2.1749
# step 3070: train loss 2.1321, val loss 2.1794
# step 3080: train loss 2.1336, val loss 2.1803
# step 3090: train loss 2.1286, val loss 2.1742
# step 3100: train loss 2.1329, val loss 2.1789
# step 3110: train loss 2.1272, val loss 2.1751
# step 3120: train loss 2.1325, val loss 2.1777
# step 3130: train loss 2.1268, val loss 2.1687
# step 3140: train loss 2.1290, val loss 2.1751
# step 3150: train loss 2.1221, val loss 2.1689
# step 3160: train loss 2.1206, val loss 2.1667
# step 3170: train loss 2.1185, val loss 2.1676
# step 3180: train loss 2.1179, val loss 2.1642
# step 3190: train loss 2.1170, val loss 2.1637
# step 3200: train loss 2.1193, val loss 2.1675
# step 3210: train loss 2.1141, val loss 2.1658
# step 3220: train loss 2.1141, val loss 2.1616
# step 3230: train loss 2.1179, val loss 2.1637
# step 3240: train loss 2.1120, val loss 2.1579
# step 3250: train loss 2.1063, val loss 2.1596
# step 3260: train loss 2.1087, val loss 2.1563
# step 3270: train loss 2.1141, val loss 2.1642
# step 3280: train loss 2.1039, val loss 2.1555
# step 3290: train loss 2.1064, val loss 2.1551
# step 3300: train loss 2.1027, val loss 2.1546
# step 3310: train loss 2.1059, val loss 2.1530
# step 3320: train loss 2.1102, val loss 2.1584
# step 3330: train loss 2.1038, val loss 2.1523
# step 3340: train loss 2.0990, val loss 2.1488
# step 3350: train loss 2.1018, val loss 2.1535
# step 3360: train loss 2.0979, val loss 2.1442
# step 3370: train loss 2.0999, val loss 2.1517
# step 3380: train loss 2.0958, val loss 2.1484
# step 3390: train loss 2.0912, val loss 2.1458
# step 3400: train loss 2.0902, val loss 2.1421
# step 3410: train loss 2.0908, val loss 2.1435
# step 3420: train loss 2.0924, val loss 2.1446
# step 3430: train loss 2.0859, val loss 2.1411
# step 3440: train loss 2.0862, val loss 2.1389
# step 3450: train loss 2.0854, val loss 2.1426
# step 3460: train loss 2.0840, val loss 2.1434
# step 3470: train loss 2.0838, val loss 2.1397
# step 3480: train loss 2.0830, val loss 2.1336
# step 3490: train loss 2.0827, val loss 2.1344
# step 3500: train loss 2.0781, val loss 2.1292
# step 3510: train loss 2.0806, val loss 2.1355
# step 3520: train loss 2.0785, val loss 2.1354
# step 3530: train loss 2.0788, val loss 2.1318
# step 3540: train loss 2.0785, val loss 2.1324
# step 3550: train loss 2.0789, val loss 2.1332
# step 3560: train loss 2.0714, val loss 2.1286
# step 3570: train loss 2.0718, val loss 2.1273
# step 3580: train loss 2.0714, val loss 2.1250
# step 3590: train loss 2.0737, val loss 2.1264
# step 3600: train loss 2.0663, val loss 2.1259
# step 3610: train loss 2.0696, val loss 2.1282
# step 3620: train loss 2.0632, val loss 2.1217
# step 3630: train loss 2.0667, val loss 2.1242
# step 3640: train loss 2.0634, val loss 2.1238
# step 3650: train loss 2.0642, val loss 2.1232
# step 3660: train loss 2.0607, val loss 2.1196
# step 3670: train loss 2.0614, val loss 2.1194
# step 3680: train loss 2.0647, val loss 2.1226
# step 3690: train loss 2.0591, val loss 2.1149
# step 3700: train loss 2.0566, val loss 2.1176
# step 3710: train loss 2.0566, val loss 2.1190
# step 3720: train loss 2.0566, val loss 2.1182
# step 3730: train loss 2.0542, val loss 2.1127
# step 3740: train loss 2.0536, val loss 2.1106
# step 3750: train loss 2.0552, val loss 2.1128
# step 3760: train loss 2.0534, val loss 2.1145
# step 3770: train loss 2.0522, val loss 2.1141
# step 3780: train loss 2.0477, val loss 2.1111
# step 3790: train loss 2.0475, val loss 2.1081
# step 3800: train loss 2.0451, val loss 2.1093
# step 3810: train loss 2.0440, val loss 2.1112
# step 3820: train loss 2.0424, val loss 2.1103
# step 3830: train loss 2.0443, val loss 2.1124
# step 3840: train loss 2.0461, val loss 2.1086
# step 3850: train loss 2.0390, val loss 2.1022
# step 3860: train loss 2.0391, val loss 2.1069
# step 3870: train loss 2.0382, val loss 2.1032
# step 3880: train loss 2.0381, val loss 2.1059
# step 3890: train loss 2.0386, val loss 2.1033
# step 3900: train loss 2.0370, val loss 2.0997
# step 3910: train loss 2.0378, val loss 2.1015
# step 3920: train loss 2.0371, val loss 2.1025
# step 3930: train loss 2.0351, val loss 2.1022
# step 3940: train loss 2.0295, val loss 2.0983
# step 3950: train loss 2.0312, val loss 2.0977
# step 3960: train loss 2.0346, val loss 2.0996
# step 3970: train loss 2.0300, val loss 2.0948
# step 3980: train loss 2.0288, val loss 2.1045
# step 3990: train loss 2.0254, val loss 2.0963
# step 4000: train loss 2.0283, val loss 2.0915
# step 4010: train loss 2.0246, val loss 2.0896
# step 4020: train loss 2.0239, val loss 2.0916
# step 4030: train loss 2.0200, val loss 2.0921
# step 4040: train loss 2.0204, val loss 2.0913
# step 4050: train loss 2.0255, val loss 2.0878
# step 4060: train loss 2.0220, val loss 2.0950
# step 4070: train loss 2.0233, val loss 2.0917
# step 4080: train loss 2.0147, val loss 2.0886
# step 4090: train loss 2.0190, val loss 2.0835
# step 4100: train loss 2.0201, val loss 2.0868
# step 4110: train loss 2.0134, val loss 2.0871
# step 4120: train loss 2.0121, val loss 2.0855
# step 4130: train loss 2.0132, val loss 2.0854
# step 4140: train loss 2.0119, val loss 2.0843
# step 4150: train loss 2.0132, val loss 2.0844
# step 4160: train loss 2.0084, val loss 2.0868
# step 4170: train loss 2.0089, val loss 2.0897
# step 4180: train loss 2.0098, val loss 2.0875
# step 4190: train loss 2.0049, val loss 2.0818
# step 4200: train loss 2.0079, val loss 2.0850
# step 4210: train loss 2.0080, val loss 2.0782
# step 4220: train loss 2.0045, val loss 2.0772
# step 4230: train loss 2.0033, val loss 2.0771
# step 4240: train loss 2.0049, val loss 2.0765
# step 4250: train loss 2.0038, val loss 2.0741
# step 4260: train loss 2.0032, val loss 2.0795
# step 4270: train loss 2.0028, val loss 2.0712
# step 4280: train loss 2.0017, val loss 2.0721
# step 4290: train loss 1.9991, val loss 2.0746
# step 4300: train loss 2.0004, val loss 2.0704
# step 4310: train loss 2.0007, val loss 2.0705
# step 4320: train loss 1.9976, val loss 2.0726
# step 4330: train loss 1.9965, val loss 2.0702
# step 4340: train loss 1.9937, val loss 2.0707
# step 4350: train loss 1.9963, val loss 2.0730
# step 4360: train loss 1.9930, val loss 2.0689
# step 4370: train loss 1.9935, val loss 2.0668
# step 4380: train loss 1.9973, val loss 2.0684
# step 4390: train loss 1.9947, val loss 2.0660
# step 4400: train loss 1.9904, val loss 2.0641
# step 4410: train loss 1.9921, val loss 2.0643
# step 4420: train loss 1.9927, val loss 2.0646
# step 4430: train loss 1.9890, val loss 2.0658
# step 4440: train loss 1.9860, val loss 2.0651
# step 4450: train loss 1.9823, val loss 2.0612
# step 4460: train loss 1.9835, val loss 2.0638
# step 4470: train loss 1.9882, val loss 2.0596
# step 4480: train loss 1.9817, val loss 2.0630
# step 4490: train loss 1.9844, val loss 2.0635
# step 4500: train loss 1.9806, val loss 2.0609
# step 4510: train loss 1.9806, val loss 2.0627
# step 4520: train loss 1.9868, val loss 2.0688
# step 4530: train loss 1.9788, val loss 2.0595
# step 4540: train loss 1.9832, val loss 2.0604
# step 4550: train loss 1.9810, val loss 2.0598
# step 4560: train loss 1.9767, val loss 2.0574
# step 4570: train loss 1.9748, val loss 2.0594
# step 4580: train loss 1.9759, val loss 2.0595
# step 4590: train loss 1.9758, val loss 2.0569
# step 4600: train loss 1.9763, val loss 2.0543
# step 4610: train loss 1.9758, val loss 2.0547
# step 4620: train loss 1.9720, val loss 2.0536
# step 4630: train loss 1.9681, val loss 2.0487
# step 4640: train loss 1.9683, val loss 2.0482
# step 4650: train loss 1.9700, val loss 2.0517
# step 4660: train loss 1.9661, val loss 2.0523
# step 4670: train loss 1.9706, val loss 2.0539
# step 4680: train loss 1.9642, val loss 2.0516
# step 4690: train loss 1.9677, val loss 2.0509
# step 4700: train loss 1.9648, val loss 2.0518
# step 4710: train loss 1.9642, val loss 2.0490
# step 4720: train loss 1.9624, val loss 2.0475
# step 4730: train loss 1.9613, val loss 2.0472
# step 4740: train loss 1.9637, val loss 2.0462
# step 4750: train loss 1.9621, val loss 2.0479
# step 4760: train loss 1.9601, val loss 2.0431
# step 4770: train loss 1.9612, val loss 2.0473
# step 4780: train loss 1.9586, val loss 2.0460
# step 4790: train loss 1.9563, val loss 2.0406
# step 4800: train loss 1.9554, val loss 2.0373
# step 4810: train loss 1.9571, val loss 2.0425
# step 4820: train loss 1.9575, val loss 2.0396
# step 4830: train loss 1.9568, val loss 2.0445
# step 4840: train loss 1.9542, val loss 2.0410
# step 4850: train loss 1.9566, val loss 2.0423
# step 4860: train loss 1.9503, val loss 2.0377
# step 4870: train loss 1.9507, val loss 2.0351
# step 4880: train loss 1.9487, val loss 2.0389
# step 4890: train loss 1.9514, val loss 2.0336
# step 4900: train loss 1.9491, val loss 2.0326
# step 4910: train loss 1.9519, val loss 2.0369
# step 4920: train loss 1.9487, val loss 2.0330
# step 4930: train loss 1.9488, val loss 2.0365
# step 4940: train loss 1.9516, val loss 2.0363
# step 4950: train loss 1.9461, val loss 2.0329
# step 4960: train loss 1.9463, val loss 2.0337
# step 4970: train loss 1.9426, val loss 2.0321
# step 4980: train loss 1.9445, val loss 2.0326
# step 4990: train loss 1.9474, val loss 2.0340

# %%
torch.save(model, "GPT model loss=2.26.model")

# %%
# generate from the model
#context = torch.zeros((1, 1), dtype=torch.long, device=device)
context = torch.tensor([tokenizer.encode_combined(list("who comes here? "))], dtype=torch.long, device=device)
print(tokenizer.decode_combined(model.generate(context, max_new_tokens=1000)[0].tolist()))
# Out:
# who comes here? fur,
# No, not bell coy on liothe con?
# Onw OF VO fine, me, too pin fayoll'd!
# And d vas what I the hor mood,: gruides, do vesth marr,
# The cocht, somel; warcitips main Jut ien;
# The cam't for hat this buthe not rdethe,
# This pithe yout whe'llurb
# sy lendese! Orfors noy gup dong, thous he los
# Swill s youllaratece the go deateth gacef kin thun sswaybljey
# The rus!
# Tho I he'lll heeat ath heal, my git thake ils my.
# Cair a mord irar, mert him with thinoufng ag fis thet fif's Mecead.
#
# YON LLARDW:
# Yocoves?
#
# NCaPS:
# Hed in waKnd oloon? mer.
#
# ISAB:
# Wem is it hertide the solat Rifleac:
# Yed,
# Thou ild Cingsty, allowsind whith pe may refut.
#
# TIS ExAncondy Noullck mayk yerserso dide-
# Toes dou th no to thir way add theriae  avergh
# Didill ove waillt, me be tobay: hou heeerin beor haisequnt faind eerew Which es swhooWh, lay, To to
# And byott ees. stouigh. I hearr pymoule! thim ot noree.
#
#
# KING RIONIN:
# Orurbl Roses!
# YOFrt sorder; yos, this heZhok he beave tromel
# And bes A mucid nous in.
# NElll'dn:
# Atounds:
# N moy t

# %% [markdown]
# ## Self-Attention
# Notes:
# - Attention is a **communication mechanism**. Can be seen as nodes in a directed graph looking at each other and aggregating information with a weighted sum from all nodes that point to them, with data-dependent weights.
# - There is no notion of space. Attention simply acts over a set of vectors. This is why we need to positionally encode tokens.
# - Each example across batch dimension is of course processed completely independently and never "talk" to each other
# - In an "encoder" attention block just delete the single line that does masking with `tril`, allowing all tokens to communicate. This block here is called a "decoder" attention block because it has triangular masking, and is usually used in autoregressive settings, like language modeling.
# - "self-attention" just means that the keys and values are produced from the same source as queries. In "cross-attention", the queries still get produced from x, but the keys and values come from some other, external source (e.g. an encoder module)
# - "Scaled" attention additional divides `wei` by 1/sqrt(head_size). This makes it so when input Q,K are unit variance, wei will be unit variance too and Softmax will stay diffuse and not saturate too much. Illustration below

# %%
B,T,C = 4,8,2
x = torch.randn(B,T,C)
x.shape
# Out:
# torch.Size([4, 8, 2])

# %%
# version 1: averaging past context with for loops, the weakest form of aggregation
# We want x[b,t] = mean_{i<=t} x[b,i]
xbow = torch.zeros((B,T,C)) # bag of words
for b in range(B):
    for t in range(T):
        xprev = x[b,:t+1] # (t,C)
        xbow[b,t] = torch.mean(xprev, 0)
print(x[0])
print(xbow[0])
# Out:
# tensor([[ 0.5658, -0.7962],
#         [-1.0757, -0.0236],
#         [ 0.2094,  1.2075],
#         [-0.5380, -0.5993],
#         [ 0.3070,  0.6486],
#         [-0.0895, -1.0398],
#         [-1.1796,  0.1757],
#         [-0.5434, -0.6277]], device='cuda:0')
# tensor([[ 0.5658, -0.7962],
#         [-0.2549, -0.4099],
#         [-0.1002,  0.1292],
#         [-0.2096, -0.0529],
#         [-0.1063,  0.0874],
#         [-0.1035, -0.1005],
#         [-0.2572, -0.0610],
#         [-0.2930, -0.1319]], device='cuda:0')

# %%
# version 2: using matrix multiply for a weighted aggregation
wei = torch.tril(torch.ones(T, T)) # Takes only the lower triangular part of of matrix, others are zero
wei = wei / wei.sum(1, keepdim=True)
xbow2 = wei @ x # (B, T, T) @ (B, T, C) ----> (B, T, C)
torch.allclose(xbow, xbow2) # same thing with version 3, but faster
# Out:
# True

# %%
# version 3: use Softmax
tril = torch.tril(torch.ones(T, T))
wei = torch.zeros((T,T))
wei = wei.masked_fill(tril == 0, float('-inf'))
wei = F.softmax(wei, dim=-1)
xbow3 = wei @ x
torch.allclose(xbow, xbow3)
# Out:
# True

# %%
# version 4: self-attention!
# difference from other is this creates a non-uniform weighted averages
torch.manual_seed(1337)
B,T,C = 4,8,32 # batch, time, channels
x = torch.randn(B,T,C)

# let's see a single Head perform self-attention
key = nn.Linear(C, n_head, bias=False) # What do I contain?
query = nn.Linear(C, n_head, bias=False) # What am I looking for?
value = nn.Linear(C, n_head, bias=False) # How the token will communicate to you, 
k = key(x)   # (B, T, head_size)
q = query(x) # (B, T, head_size)
wei =  q @ k.transpose(-2, -1) # (B, T, head_size) @ (B, head_size, T) ---> (B, T, T)
wei *= n_head**-0.5 # scaled, otherwise softmax would be way too peaky!!

tril = torch.tril(torch.ones(T, T))
#wei = torch.zeros((T,T))
wei = wei.masked_fill(tril == 0, float('-inf')) # remove this to make it encoder attention block, allowing all tokens to communicate
wei = F.softmax(wei, dim=-1) 

v = value(x)
out = wei @ v
#out = wei @ x

out.shape # (B, T, head_size)
# Out:
# torch.Size([4, 8, 4])

# %% [markdown]
# ## Train a GPT model to add n-digit numbers
# https://github.com/karpathy/minGPT/tree/master/projects/adder
